# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/archive.zip' -d '/content/drive/MyDrive/archive'
# Out:
# Archive:  /content/drive/MyDrive/archive.zip
# replace /content/drive/MyDrive/archive/fruits-360/LICENSE? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
data_dir = '/content/drive/MyDrive/archive/fruits-360_dataset/fruits-360/'

train_dataset = ImageFolder(data_dir + "Training", transform=ToTensor())

test_dataset = ImageFolder(data_dir + "Test", transform=ToTensor())

# %%
dataset_size = len(train_dataset)
test_dataset_size = len(test_dataset)
print(train_dataset)
print(test_dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 52262
#     Root location: /content/drive/MyDrive/archive/fruits-360_dataset/fruits-360/Training
#     StandardTransform
# Transform: ToTensor()
# Dataset ImageFolder
#     Number of datapoints: 17540
#     Root location: /content/drive/MyDrive/archive/fruits-360_dataset/fruits-360/Test
#     StandardTransform
# Transform: ToTensor()

# %%
# print(os.listdir(data_dir))
classes = os.listdir(data_dir + "Training")
print(f'Total Number of Classe {len(classes)}')
print(f'Classes Names: {classes}')
# Out:
# Total Number of Classe 101
# Classes Names: ['Apple Braeburn', 'Apple Crimson Snow', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow 1', 'Apple Red Yellow 2', 'Apricot', 'Avocado ripe', 'Avocado', 'Banana Lady Finger', 'Banana Red', 'Banana', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Chestnut', 'Clementine', 'Cocos', 'Dates', 'Granadilla', 'Grape Blue', 'Grape Pink', 'Grape White 2', 'Grape White 3', 'Grape White 4', 'Grape White', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon Meyer', 'Lemon', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mangostan', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Orange', 'Papaya', 'Passion Fruit', 'Peach 2', 'Peach Flat', 'Peach', 'Pear Abate', 'Pear Kaiser', 'Pear Monster', 'Pear Red', 'Pear Williams', 'Pear', 'Pepino', 'Pepper Green', 'Pepper Red', 'Pepper Yellow', 'Physalis with Husk', 'Physalis', 'Pineapple Mini', 'Pineapple', 'Pitahaya Red', 'Plum 2', 'Plum 3', 'Plum', 'Pomegranate', 'Pomelo Sweetie', 'Quince', 'Rambutan', 'Raspberry', 'Redcurrant', 'Salak', 'Strawberry Wedge', 'Strawberry', 'Tamarillo', 'Tangelo', 'Tomato 1', 'Tomato 2', 'Tomato 3', 'Tomato 4', 'Tomato Cherry Red', 'Tomato Maroon', 'Walnut']

# %%
img, label = train_dataset[0]
img_shape = img.shape
img_shape
# Out:
# torch.Size([3, 100, 100])

# %%
img, label = train_dataset[0]
plt.imshow(img.permute((1, 2, 0)))
print('Label (numeric):', label)
print('Label (textual):', classes[label])
# Out:
# Label (numeric): 0
# Label (textual): Apple Braeburn

# %%
dataset_size = len(train_dataset)
classes = train_dataset.classes
num_classes = len(train_dataset.classes)

img_dict = {}
for i in range(num_classes):
    img_dict[classes[i]] = 0
    
for i in range(dataset_size):
    img, label = train_dataset[i]
    img_dict[classes[label]] += 1


## Plotting classes along with images info

from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize =(16, 32))

ax.barh(list(img_dict.keys()), list(img_dict.values()))



# Add Plot Title
ax.set_title('Each Class along with their values',
             loc ='left', )

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')

# Add Text watermark
fig.text(0.9, 0.15, 'gurjeet333', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-312592787f39> in <module>
#       8
#       9 for i in range(dataset_size):
# ---> 10     img, label = train_dataset[i]
#      11     img_dict[classes[label]] += 1
#      12
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     228         """
#     229         path, target = self.samples[index]
# --> 230         sample = self.loader(path)
#     231         if self.transform is not None:
#     232             sample = self.transform(sample)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     267         return accimage_loader(path)
#     268     else:
# --> 269         return pil_loader(path)
#     270
#     271
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     246     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     247     with open(path, "rb") as f:
# --> 248         img = Image.open(f)
#     249         return img.convert("RGB")
#     250
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2850         exclusive_fp = True
#    2851
# -> 2852     prefix = fp.read(16)
#    2853
#    2854     preinit()
#
# KeyboardInterrupt:

# %%
# 데이터 변형(데이터 augmentation)
train_tfms = tt.Compose([
                         tt.RandomCrop(100, padding=4, padding_mode='reflect'), 
                         tt.Resize((100,100)),
                         tt.RandomHorizontalFlip(), 
                         tt.RandomRotation,
                         tt.RandomResizedCrop(256, scale=(0.5,0.9), ratio=(1, 1)), 
                         tt.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
                         tt.ToTensor(), 
                         ])
valid_tfms = tt.Compose([tt.ToTensor(), tt.Resize((100,100)),
                         ])

# %%
dataset = ImageFolder(data_dir + "/Training", transform=train_tfms)

Testing = ImageFolder(data_dir + "/Test", transform=valid_tfms)

# %%
torch.manual_seed(43)
val_size = round(len(dataset) * 0.2)
train_size = round(len(dataset) - val_size)

train_ds, val_ds = random_split(dataset, [train_size, val_size])
len(train_ds), len(val_ds)
# Out:
# (41810, 10452)

# %%
batch_size=400

train_loader = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size*2, num_workers=4, pin_memory=True)

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
        break

show_batch(train_loader)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device

train_dl = DeviceDataLoader(train_loader, device)
valid_dl = DeviceDataLoader(val_loader, device)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # 예측생성
        loss = F.cross_entropy(out, labels) # loss값 계산
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # 예측생성
        loss = F.cross_entropy(out, labels)   # loss값 계산
        acc = accuracy(out, labels)           # 정확도 계산
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   #loss값 결합
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # 정확도 결합
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class Fruit360CnnModel(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            
            nn.Conv2d(3, 16, kernel_size=2, padding=1), 
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # 16 X 50 X 50

            nn.Conv2d(16, 32, kernel_size=2, stride=1, padding=1), 
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # 32 X 25 X 25

            nn.Conv2d(32, 64, kernel_size=2, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(5, 5), # 64 X 5 X 5

            nn.Flatten(), 
            nn.Dropout(0.3),
            nn.ReLU(),
            nn.Linear(64*5*5, 131))
        
    def forward(self, xb):
      return self.network(xb)

model = Fruit360CnnModel()
model
# Out:
# Fruit360CnnModel(
#   (network): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(32, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Dropout(p=0.3, inplace=False)
#     (14): ReLU()
#     (15): Linear(in_features=1600, out_features=131, bias=True)
#   )
# )

# %%
@torch.no_grad()

def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # 가중치 감쇠로 weight값 조정하기
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # one-cycle 학습률 스케줄링
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    for epoch in range(epochs):
        # 학습데이터 구간
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # 그래디언트 클리핑
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # 학습률 수정
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # validation 구간
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
# Moving the model to GPU
model = to_device(model, device)
model
# Out:
# Fruit360CnnModel(
#   (network): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(32, 64, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (12): Flatten(start_dim=1, end_dim=-1)
#     (13): Dropout(p=0.3, inplace=False)
#     (14): ReLU()
#     (15): Linear(in_features=1600, out_features=131, bias=True)
#   )
# )

# %%
os.environ['WANDB_CONSOLE'] = 'off'

history = [evaluate(model, valid_dl)]
history
# Out:
# [{'val_loss': 4.874469757080078, 'val_acc': 0.010034340433776379}]

# %%
epochs = 4
max_lr = 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
# %%time

os.environ['WANDB_CONSOLE'] = 'off'

history += fit_one_cycle(epochs, max_lr, model, train_dl, valid_dl, 
                             grad_clip=grad_clip, 
                             weight_decay=weight_decay, 
                             opt_func=opt_func)
# Out:
# Epoch [0], train_loss: 1.2018, val_loss: 1.0549, val_acc: 0.6994
# Epoch [1], train_loss: 0.1050, val_loss: 0.1624, val_acc: 0.9431
# Epoch [2], train_loss: 0.0133, val_loss: 0.0026, val_acc: 0.9994
# Epoch [3], train_loss: 0.0039, val_loss: 0.0006, val_acc: 0.9999
# CPU times: user 20.1 s, sys: 9.19 s, total: 29.3 s
# Wall time: 42min 19s

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs epoch수');

plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs epoch수');

plot_losses(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch수');

plot_lrs(history)

# %%
test_tfms = tt.Compose([tt.Resize((100, 100)), 
                        tt.ToTensor()])

# %%
test_dataset = ImageFolder(data_dir + "Test", transform=test_tfms)

# %%
test_loader = DeviceDataLoader(DataLoader(test_dataset, batch_size), device)
result = evaluate(model, test_loader)
result
# Out:
# {'val_loss': 0.013513550162315369, 'val_acc': 0.995795488357544}

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %%
img, label = test_dataset[0]
plt.imshow(img.permute(1, 2, 0))
print('label값:', dataset.classes[label], '예측값:', predict_image(img, model))
# Out:
# label값: Apple Braeburn 예측값: Apple Braeburn

# %%
img, label = test_dataset[513]
plt.imshow(img.permute(1, 2, 0))
print('label값:', dataset.classes[label], ', 예측값:', predict_image(img, model))
# Out:
# label값: Apple Golden 2 , 예측값: Apple Golden 2

# %%
img, label = test_dataset[10000]
plt.imshow(img.permute(1, 2, 0))
print('label값:', dataset.classes[label], ', 예측값:', predict_image(img, model))
# Out:
# label값: Nectarine , 예측값: Nectarine

# %%
for i in range(len(test_dataset)):
  img, label = test_dataset[i]
  plt.imshow(img.permute(1, 2, 0))
  print('label값:', dataset.classes[label], '예측값:', predict_image(img, model), i)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# label값: Pepper Red 예측값: Pepper Red 12540
# label값: Pepper Red 예측값: Pepper Red 12541
# label값: Pepper Red 예측값: Pepper Red 12542
# label값: Pepper Red 예측값: Pepper Red 12543
# label값: Pepper Red 예측값: Pepper Red 12544
# label값: Pepper Red 예측값: Pepper Red 12545
# label값: Pepper Red 예측값: Pepper Red 12546
# label값: Pepper Red 예측값: Pepper Red 12547
# label값: Pepper Red 예측값: Pepper Red 12548
# label값: Pepper Red 예측값: Pepper Red 12549
# label값: Pepper Red 예측값: Pepper Red 12550
# label값: Pepper Red 예측값: Pepper Red 12551
# label값: Pepper Red 예측값: Pepper Red 12552
# label값: Pepper Red 예측값: Pepper Red 12553
# label값: Pepper Red 예측값: Pepper Red 12554
# label값: Pepper Red 예측값: Pepper Red 12555
# label값: Pepper Red 예측값: Pepper Red 12556
# label값: Pepper Red 예측값: Pepper Red 12557
# label값: Pepper Red 예측값: Pepper Red 12558
# label값: Pepper Red 예측값: Pepper Red 12559
# label값: Pepper Red 예측값: Pepper Red 12560
# label값: Pepper Red 예측값: Pepper Red 12561
# label값: Pepper Red 예측값: Pepper Red 12562
# label값: Pepper Red 예측값: Pepper Red 12563
# label값: Pepper Red 예측값: Pepper Red 12564
# label값: Pepper Red 예측값: Pepper Red 12565
# label값: Pepper Red 예측값: Pepper Red 12566
# label값: Pepper Red 예측값: Pepper Red 12567
# label값: Pepper Red 예측값: Pepper Red 12568
# label값: Pepper Red 예측값: Pepper Red 12569
# label값: Pepper Red 예측값: Pepper Red 12570
# label값: Pepper Red 예측값: Pepper Red 12571
# label값: Pepper Red 예측값: Pepper Red 12572
# label값: Pepper Red 예측값: Pepper Red 12573
# label값: Pepper Red 예측값: Pepper Red 12574
# label값: Pepper Red 예측값: Pepper Red 12575
# label값: Pepper Red 예측값: Pepper Red 12576
# label값: Pepper Red 예측값: Pepper Red 12577
# label값: Pepper Red 예측값: Pepper Red 12578
# label값: Pepper Red 예측값: Pepper Red 12579
# label값: Pepper Red 예측값: Pepper Red 12580
# label값: Pepper Red 예측값: Pepper Red 12581
# label값: Pepper Red 예측값: Pepper Red 12582
# label값: Pepper Red 예측값: Pepper Red 12583
# label값: Pepper Red 예측값: Pepper Red 12584
# label값: Pepper Red 예측값: Pepper Red 12585
# label값: Pepper Red 예측값: Pepper Red 12586
# label값: Pepper Red 예측값: Pepper Red 12587
# label값: Pepper Red 예측값: Pepper Red 12588
# label값: Pepper Red 예측값: Pepper Red 12589
# label값: Pepper Red 예측값: Pepper Red 12590
# label값: Pepper Red 예측값: Pepper Red 12591
# label값: Pepper Red 예측값: Pepper Red 12592
# label값: Pepper Red 예측값: Pepper Red 12593
# label값: Pepper Red 예측값: Pepper Red 12594
# label값: Pepper Red 예측값: Pepper Red 12595
# label값: Pepper Red 예측값: Pepper Red 12596
# label값: Pepper Red 예측값: Pepper Red 12597
# label값: Pepper Red 예측값: Pepper Red 12598
# label값: Pepper Red 예측값: Pepper Red 12599
# label값: Pepper Yellow 예측값: Pepper Yellow 12600
# label값: Pepper Yellow 예측값: Pepper Yellow 12601
# label값: Pepper Yellow 예측값: Pepper Yellow 12602
# label값: Pepper Yellow 예측값: Pepper Yellow 12603
# label값: Pepper Yellow 예측값: Pepper Yellow 12604
# label값: Pepper Yellow 예측값: Pepper Yellow 12605
# label값: Pepper Yellow 예측값: Pepper Yellow 12606
# label값: Pepper Yellow 예측값: Pepper Yellow 12607
# label값: Pepper Yellow 예측값: Pepper Yellow 12608
# label값: Pepper Yellow 예측값: Pepper Yellow 12609
# label값: Pepper Yellow 예측값: Pepper Yellow 12610
# label값: Pepper Yellow 예측값: Pepper Yellow 12611
# label값: Pepper Yellow 예측값: Pepper Yellow 12612
# label값: Pepper Yellow 예측값: Pepper Yellow 12613
# label값: Pepper Yellow 예측값: Pepper Yellow 12614
# label값: Pepper Yellow 예측값: Pepper Yellow 12615
# label값: Pepper Yellow 예측값: Pepper Yellow 12616
# label값: Pepper Yellow 예측값: Pepper Yellow 12617
# label값: Pepper Yellow 예측값: Pepper Yellow 12618
# label값: Pepper Yellow 예측값: Pepper Yellow 12619
# label값: Pepper Yellow 예측값: Pepper Yellow 12620
# label값: Pepper Yellow 예측값: Pepper Yellow 12621
# label값: Pepper Yellow 예측값: Pepper Yellow 12622
# label값: Pepper Yellow 예측값: Pepper Yellow 12623
# label값: Pepper Yellow 예측값: Pepper Yellow 12624
# label값: Pepper Yellow 예측값: Pepper Yellow 12625
# label값: Pepper Yellow 예측값: Pepper Yellow 12626
# label값: Pepper Yellow 예측값: Pepper Yellow 12627
# label값: Pepper Yellow 예측값: Pepper Yellow 12628
# label값: Pepper Yellow 예측값: Pepper Yellow 12629
# label값: Pepper Yellow 예측값: Pepper Yellow 12630
# label값: Pepper Yellow 예측값: Pepper Yellow 12631
# label값: Pepper Yellow 예측값: Pepper Yellow 12632
# label값: Pepper Yellow 예측값: Pepper Yellow 12633
# label값: Pepper Yellow 예측값: Pepper Yellow 12634
# label값: Pepper Yellow 예측값: Pepper Yellow 12635
# label값: Pepper Yellow 예측값: Pepper Yellow 12636
# label값: Pepper Yellow 예측값: Pepper Yellow 12637
# label값: Pepper Yellow 예측값: Pepper Yellow 12638
# label값: Pepper Yellow 예측값: Pepper Yellow 12639
# label값: Pepper Yellow 예측값: Pepper Yellow 12640
# label값: Pepper Yellow 예측값: Pepper Yellow 12641
# label값: Pepper Yellow 예측값: Pepper Yellow 12642
# label값: Pepper Yellow 예측값: Pepper Yellow 12643
# label값: Pepper Yellow 예측값: Pepper Yellow 12644
# label값: Pepper Yellow 예측값: Pepper Yellow 12645
# label값: Pepper Yellow 예측값: Pepper Yellow 12646
# label값: Pepper Yellow 예측값: Pepper Yellow 12647
# label값: Pepper Yellow 예측값: Pepper Yellow 12648
# label값: Pepper Yellow 예측값: Pepper Yellow 12649
# label값: Pepper Yellow 예측값: Pepper Yellow 12650
# label값: Pepper Yellow 예측값: Pepper Yellow 12651
# label값: Pepper Yellow 예측값: Pepper Yellow 12652
# label값: Pepper Yellow 예측값: Pepper Yellow 12653
# label값: Pepper Yellow 예측값: Pepper Yellow 12654
# label값: Pepper Yellow 예측값: Pepper Yellow 12655
# label값: Pepper Yellow 예측값: Pepper Yellow 12656
# label값: Pepper Yellow 예측값: Pepper Yellow 12657
# label값: Pepper Yellow 예측값: Pepper Yellow 12658
# label값: Pepper Yellow 예측값: Pepper Yellow 12659
# label값: Pepper Yellow 예측값: Pepper Yellow 12660
# label값: Pepper Yellow 예측값: Pepper Yellow 12661
# label값: Pepper Yellow 예측값: Pepper Yellow 12662
# label값: Pepper Yellow 예측값: Pepper Yellow 12663
# label값: Pepper Yellow 예측값: Pepper Yellow 12664
# label값: Pepper Yellow 예측값: Pepper Yellow 12665
# label값: Pepper Yellow 예측값: Pepper Yellow 12666
# label값: Pepper Yellow 예측값: Pepper Yellow 12667
# label값: Pepper Yellow 예측값: Pepper Yellow 12668
# label값: Pepper Yellow 예측값: Pepper Yellow 12669
# label값: Pepper Yellow 예측값: Pepper Yellow 12670
# label값: Pepper Yellow 예측값: Pepper Yellow 12671
# label값: Pepper Yellow 예측값: Pepper Yellow 12672
# label값: Pepper Yellow 예측값: Pepper Yellow 12673
# label값: Pepper Yellow 예측값: Pepper Yellow 12674
# label값: Pepper Yellow 예측값: Pepper Yellow 12675
# label값: Pepper Yellow 예측값: Pepper Yellow 12676
# label값: Pepper Yellow 예측값: Pepper Yellow 12677
# label값: Pepper Yellow 예측값: Pepper Yellow 12678
# label값: Pepper Yellow 예측값: Pepper Yellow 12679
# label값: Pepper Yellow 예측값: Pepper Yellow 12680
# label값: Pepper Yellow 예측값: Pepper Yellow 12681
# label값: Pepper Yellow 예측값: Pepper Yellow 12682
# label값: Pepper Yellow 예측값: Pepper Yellow 12683
# label값: Pepper Yellow 예측값: Pepper Yellow 12684
# label값: Pepper Yellow 예측값: Pepper Yellow 12685
# label값: Pepper Yellow 예측값: Pepper Yellow 12686
# label값: Pepper Yellow 예측값: Pepper Yellow 12687
# label값: Pepper Yellow 예측값: Pepper Yellow 12688
# label값: Pepper Yellow 예측값: Pepper Yellow 12689
# label값: Pepper Yellow 예측값: Pepper Yellow 12690
# label값: Pepper Yellow 예측값: Pepper Yellow 12691
# label값: Pepper Yellow 예측값: Pepper Yellow 12692
# label값: Pepper Yellow 예측값: Pepper Yellow 12693
# label값: Pepper Yellow 예측값: Pepper Yellow 12694
# label값: Pepper Yellow 예측값: Pepper Yellow 12695
# label값: Pepper Yellow 예측값: Pepper Yellow 12696
# label값: Pepper Yellow 예측값: Pepper Yellow 12697
# label값: Pepper Yellow 예측값: Pepper Yellow 12698
# label값: Pepper Yellow 예측값: Pepper Yellow 12699
# label값: Pepper Yellow 예측값: Pepper Yellow 12700
# label값: Pepper Yellow 예측값: Pepper Yellow 12701
# label값: Pepper Yellow 예측값: Pepper Yellow 12702
# label값: Pepper Yellow 예측값: Pepper Yellow 12703
# label값: Pepper Yellow 예측값: Pepper Yellow 12704
# label값: Pepper Yellow 예측값: Pepper Yellow 12705
# label값: Pepper Yellow 예측값: Pepper Yellow 12706
# label값: Pepper Yellow 예측값: Pepper Yellow 12707
# label값: Pepper Yellow 예측값: Pepper Yellow 12708
# label값: Pepper Yellow 예측값: Pepper Yellow 12709
# label값: Pepper Yellow 예측값: Pepper Yellow 12710
# label값: Pepper Yellow 예측값: Pepper Yellow 12711
# label값: Pepper Yellow 예측값: Pepper Yellow 12712
# label값: Pepper Yellow 예측값: Pepper Yellow 12713
# label값: Pepper Yellow 예측값: Pepper Yellow 12714
# label값: Pepper Yellow 예측값: Pepper Yellow 12715
# label값: Pepper Yellow 예측값: Pepper Yellow 12716
# label값: Pepper Yellow 예측값: Pepper Yellow 12717
# label값: Pepper Yellow 예측값: Pepper Yellow 12718
# label값: Pepper Yellow 예측값: Pepper Yellow 12719
# label값: Pepper Yellow 예측값: Pepper Yellow 12720
# label값: Pepper Yellow 예측값: Pepper Yellow 12721
# label값: Pepper Yellow 예측값: Pepper Yellow 12722
# label값: Pepper Yellow 예측값: Pepper Yellow 12723
# label값: Pepper Yellow 예측값: Pepper Yellow 12724
# label값: Pepper Yellow 예측값: Pepper Yellow 12725
# label값: Pepper Yellow 예측값: Pepper Yellow 12726
# label값: Pepper Yellow 예측값: Pepper Yellow 12727
# label값: Pepper Yellow 예측값: Pepper Yellow 12728
# label값: Pepper Yellow 예측값: Pepper Yellow 12729
# label값: Pepper Yellow 예측값: Pepper Yellow 12730
# label값: Pepper Yellow 예측값: Pepper Yellow 12731
# label값: Pepper Yellow 예측값: Pepper Yellow 12732
# label값: Pepper Yellow 예측값: Pepper Yellow 12733
# label값: Pepper Yellow 예측값: Pepper Yellow 12734
# label값: Pepper Yellow 예측값: Pepper Yellow 12735
# label값: Pepper Yellow 예측값: Pepper Yellow 12736
# label값: Pepper Yellow 예측값: Pepper Yellow 12737
# label값: Pepper Yellow 예측값: Pepper Yellow 12738
# label값: Pepper Yellow 예측값: Pepper Yellow 12739
# label값: Pepper Yellow 예측값: Pepper Yellow 12740
# label값: Pepper Yellow 예측값: Pepper Yellow 12741
# label값: Pepper Yellow 예측값: Pepper Yellow 12742
# label값: Pepper Yellow 예측값: Pepper Yellow 12743
# label값: Pepper Yellow 예측값: Pepper Yellow 12744
# label값: Pepper Yellow 예측값: Pepper Yellow 12745
# label값: Pepper Yellow 예측값: Pepper Yellow 12746
# label값: Pepper Yellow 예측값: Pepper Yellow 12747
# label값: Pepper Yellow 예측값: Pepper Yellow 12748
# label값: Pepper Yellow 예측값: Pepper Yellow 12749
# label값: Pepper Yellow 예측값: Pepper Yellow 12750
# label값: Pepper Yellow 예측값: Pepper Yellow 12751
# label값: Pepper Yellow 예측값: Pepper Yellow 12752
# label값: Pepper Yellow 예측값: Pepper Yellow 12753
# label값: Pepper Yellow 예측값: Pepper Yellow 12754
# label값: Pepper Yellow 예측값: Pepper Yellow 12755
# label값: Pepper Yellow 예측값: Pepper Yellow 12756
# label값: Pepper Yellow 예측값: Pepper Yellow 12757
# label값: Pepper Yellow 예측값: Pepper Yellow 12758
# label값: Pepper Yellow 예측값: Pepper Yellow 12759
# label값: Pepper Yellow 예측값: Pepper Yellow 12760
# label값: Pepper Yellow 예측값: Pepper Yellow 12761
# label값: Pepper Yellow 예측값: Pepper Yellow 12762
# label값: Pepper Yellow 예측값: Pepper Yellow 12763
# label값: Pepper Yellow 예측값: Pepper Yellow 12764
# label값: Pepper Yellow 예측값: Pepper Yellow 12765
# label값: Pepper Yellow 예측값: Pepper Yellow 12766
# label값: Pepper Yellow 예측값: Pepper Yellow 12767
# label값: Pepper Yellow 예측값: Pepper Yellow 12768
# label값: Pepper Yellow 예측값: Pepper Yellow 12769
# label값: Pepper Yellow 예측값: Pepper Yellow 12770
# label값: Pepper Yellow 예측값: Pepper Yellow 12771
# label값: Pepper Yellow 예측값: Pepper Yellow 12772
# label값: Pepper Yellow 예측값: Pepper Yellow 12773
# label값: Pepper Yellow 예측값: Pepper Yellow 12774
# label값: Pepper Yellow 예측값: Pepper Yellow 12775
# label값: Pepper Yellow 예측값: Pepper Yellow 12776
# label값: Pepper Yellow 예측값: Pepper Yellow 12777
# label값: Pepper Yellow 예측값: Pepper Yellow 12778
# label값: Pepper Yellow 예측값: Pepper Yellow 12779
# label값: Pepper Yellow 예측값: Pepper Yellow 12780
# label값: Pepper Yellow 예측값: Pepper Yellow 12781
# label값: Pepper Yellow 예측값: Pepper Yellow 12782
# label값: Pepper Yellow 예측값: Pepper Yellow 12783
# label값: Pepper Yellow 예측값: Pepper Yellow 12784
# label값: Pepper Yellow 예측값: Pepper Yellow 12785
# label값: Pepper Yellow 예측값: Pepper Yellow 12786
# label값: Pepper Yellow 예측값: Pepper Yellow 12787
# label값: Pepper Yellow 예측값: Pepper Yellow 12788
# label값: Pepper Yellow 예측값: Pepper Yellow 12789
# label값: Pepper Yellow 예측값: Pepper Yellow 12790
# label값: Pepper Yellow 예측값: Pepper Yellow 12791
# label값: Pepper Yellow 예측값: Pepper Yellow 12792
# label값: Pepper Yellow 예측값: Pepper Yellow 12793
# label값: Pepper Yellow 예측값: Pepper Yellow 12794
# label값: Pepper Yellow 예측값: Pepper Yellow 12795
# label값: Pepper Yellow 예측값: Pepper Yellow 12796
# label값: Pepper Yellow 예측값: Pepper Yellow 12797
# label값: Pepper Yellow 예측값: Pepper Yellow 12798
# label값: Pepper Yellow 예측값: Pepper Yellow 12799
# label값: Pepper Yellow 예측값: Pepper Yellow 12800
# label값: Pepper Yellow 예측값: Pepper Yellow 12801
# label값: Pepper Yellow 예측값: Pepper Yellow 12802
# label값: Pepper Yellow 예측값: Pepper Yellow 12803
# label값: Pepper Yellow 예측값: Pepper Yellow 12804
# label값: Pepper Yellow 예측값: Pepper Yellow 12805
# label값: Pepper Yellow 예측값: Pepper Yellow 12806
# label값: Pepper Yellow 예측값: Pepper Yellow 12807
# label값: Pepper Yellow 예측값: Pepper Yellow 12808
# label값: Pepper Yellow 예측값: Pepper Yellow 12809
# label값: Pepper Yellow 예측값: Pepper Yellow 12810
# label값: Pepper Yellow 예측값: Pepper Yellow 12811
# label값: Pepper Yellow 예측값: Pepper Yellow 12812
# label값: Pepper Yellow 예측값: Pepper Yellow 12813
# label값: Pepper Yellow 예측값: Pepper Yellow 12814
# label값: Pepper Yellow 예측값: Pepper Yellow 12815
# label값: Pepper Yellow 예측값: Pepper Yellow 12816
# label값: Pepper Yellow 예측값: Pepper Yellow 12817
# label값: Pepper Yellow 예측값: Pepper Yellow 12818
# label값: Pepper Yellow 예측값: Pepper Yellow 12819
# label값: Pepper Yellow 예측값: Pepper Yellow 12820
# label값: Pepper Yellow 예측값: Pepper Yellow 12821
# label값: Physalis 예측값: Physalis 12822
# label값: Physalis 예측값: Physalis 12823
# label값: Physalis 예측값: Physalis 12824
# label값: Physalis 예측값: Physalis 12825
# label값: Physalis 예측값: Physalis 12826
# label값: Physalis 예측값: Physalis 12827
# label값: Physalis 예측값: Physalis 12828
# label값: Physalis 예측값: Physalis 12829
# label값: Physalis 예측값: Physalis 12830
# label값: Physalis 예측값: Physalis 12831
# label값: Physalis 예측값: Physalis 12832
# label값: Physalis 예측값: Physalis 12833
# label값: Physalis 예측값: Physalis 12834
# label값: Physalis 예측값: Physalis 12835
# label값: Physalis 예측값: Physalis 12836
# label값: Physalis 예측값: Physalis 12837
# label값: Physalis 예측값: Physalis 12838
# label값: Physalis 예측값: Physalis 12839
# label값: Physalis 예측값: Physalis 12840
# label값: Physalis 예측값: Physalis 12841
# label값: Physalis 예측값: Physalis 12842
# label값: Physalis 예측값: Physalis 12843
# label값: Physalis 예측값: Physalis 12844
# label값: Physalis 예측값: Physalis 12845
# label값: Physalis 예측값: Physalis 12846
# label값: Physalis 예측값: Physalis 12847
# label값: Physalis 예측값: Physalis 12848
# label값: Physalis 예측값: Physalis 12849
# label값: Physalis 예측값: Physalis 12850
# label값: Physalis 예측값: Physalis 12851
# label값: Physalis 예측값: Physalis 12852
# label값: Physalis 예측값: Physalis 12853
# label값: Physalis 예측값: Physalis 12854
# label값: Physalis 예측값: Physalis 12855
# label값: Physalis 예측값: Physalis 12856
# label값: Physalis 예측값: Physalis 12857
# label값: Physalis 예측값: Physalis 12858
# label값: Physalis 예측값: Physalis 12859
# label값: Physalis 예측값: Physalis 12860
# label값: Physalis 예측값: Physalis 12861
# label값: Physalis 예측값: Physalis 12862
# label값: Physalis 예측값: Physalis 12863
# label값: Physalis 예측값: Physalis 12864
# label값: Physalis 예측값: Physalis 12865
# label값: Physalis 예측값: Physalis 12866
# label값: Physalis 예측값: Physalis 12867
# label값: Physalis 예측값: Physalis 12868
# label값: Physalis 예측값: Physalis 12869
# label값: Physalis 예측값: Physalis 12870
# label값: Physalis 예측값: Physalis 12871
# label값: Physalis 예측값: Physalis 12872
# label값: Physalis 예측값: Physalis 12873
# label값: Physalis 예측값: Physalis 12874
# label값: Physalis 예측값: Physalis 12875
# label값: Physalis 예측값: Physalis 12876
# label값: Physalis 예측값: Physalis 12877
# label값: Physalis 예측값: Physalis 12878
# label값: Physalis 예측값: Physalis 12879
# label값: Physalis 예측값: Physalis 12880
# label값: Physalis 예측값: Physalis 12881
# label값: Physalis 예측값: Physalis 12882
# label값: Physalis 예측값: Physalis 12883
# label값: Physalis 예측값: Physalis 12884
# label값: Physalis 예측값: Physalis 12885
# label값: Physalis 예측값: Physalis 12886
# label값: Physalis 예측값: Physalis 12887
# label값: Physalis 예측값: Physalis 12888
# label값: Physalis 예측값: Physalis 12889
# label값: Physalis 예측값: Physalis 12890
# label값: Physalis 예측값: Physalis 12891
# label값: Physalis 예측값: Physalis 12892
# label값: Physalis 예측값: Physalis 12893
# label값: Physalis 예측값: Physalis 12894
# label값: Physalis 예측값: Physalis 12895
# label값: Physalis 예측값: Physalis 12896
# label값: Physalis 예측값: Physalis 12897
# label값: Physalis 예측값: Physalis 12898
# label값: Physalis 예측값: Physalis 12899
# label값: Physalis 예측값: Physalis 12900
# label값: Physalis 예측값: Physalis 12901
# label값: Physalis 예측값: Physalis 12902
# label값: Physalis 예측값: Physalis 12903
# label값: Physalis 예측값: Physalis 12904
# label값: Physalis 예측값: Physalis 12905
# label값: Physalis 예측값: Physalis 12906
# label값: Physalis 예측값: Physalis 12907
# label값: Physalis 예측값: Physalis 12908
# label값: Physalis 예측값: Physalis 12909
# label값: Physalis 예측값: Physalis 12910
# label값: Physalis 예측값: Physalis 12911
# label값: Physalis 예측값: Physalis 12912
# label값: Physalis 예측값: Physalis 12913
# label값: Physalis 예측값: Physalis 12914
# label값: Physalis 예측값: Physalis 12915
# label값: Physalis 예측값: Physalis 12916
# label값: Physalis 예측값: Physalis 12917
# label값: Physalis 예측값: Physalis 12918
# label값: Physalis 예측값: Physalis 12919
# label값: Physalis 예측값: Physalis 12920
# label값: Physalis 예측값: Physalis 12921
# label값: Physalis 예측값: Physalis 12922
# label값: Physalis 예측값: Physalis 12923
# label값: Physalis 예측값: Physalis 12924
# label값: Physalis 예측값: Physalis 12925
# label값: Physalis 예측값: Physalis 12926
# label값: Physalis 예측값: Physalis 12927
# label값: Physalis 예측값: Physalis 12928
# label값: Physalis 예측값: Physalis 12929
# label값: Physalis 예측값: Physalis 12930
# label값: Physalis 예측값: Physalis 12931
# label값: Physalis 예측값: Physalis 12932
# label값: Physalis 예측값: Physalis 12933
# label값: Physalis 예측값: Physalis 12934
# label값: Physalis 예측값: Physalis 12935
# label값: Physalis 예측값: Physalis 12936
# label값: Physalis 예측값: Physalis 12937
# label값: Physalis 예측값: Physalis 12938
# label값: Physalis 예측값: Physalis 12939
# label값: Physalis 예측값: Physalis 12940
# label값: Physalis 예측값: Physalis 12941
# label값: Physalis 예측값: Physalis 12942
# label값: Physalis 예측값: Physalis 12943
# label값: Physalis 예측값: Physalis 12944
# label값: Physalis 예측값: Physalis 12945
# label값: Physalis 예측값: Physalis 12946
# label값: Physalis 예측값: Physalis 12947
# label값: Physalis 예측값: Physalis 12948
# label값: Physalis 예측값: Physalis 12949
# label값: Physalis 예측값: Physalis 12950
# label값: Physalis 예측값: Physalis 12951
# label값: Physalis 예측값: Physalis 12952
# label값: Physalis 예측값: Physalis 12953
# label값: Physalis 예측값: Physalis 12954
# label값: Physalis 예측값: Physalis 12955
# label값: Physalis 예측값: Physalis 12956
# label값: Physalis 예측값: Physalis 12957
# label값: Physalis 예측값: Physalis 12958
# label값: Physalis 예측값: Physalis 12959
# label값: Physalis 예측값: Physalis 12960
# label값: Physalis 예측값: Physalis 12961
# label값: Physalis 예측값: Physalis 12962
# label값: Physalis 예측값: Physalis 12963
# label값: Physalis 예측값: Physalis 12964
# label값: Physalis 예측값: Physalis 12965
# label값: Physalis 예측값: Physalis 12966
# label값: Physalis 예측값: Physalis 12967
# label값: Physalis 예측값: Physalis 12968
# label값: Physalis 예측값: Physalis 12969
# label값: Physalis 예측값: Physalis 12970
# label값: Physalis 예측값: Physalis 12971
# label값: Physalis 예측값: Physalis 12972
# label값: Physalis 예측값: Physalis 12973
# label값: Physalis 예측값: Physalis 12974
# label값: Physalis 예측값: Physalis 12975
# label값: Physalis 예측값: Physalis 12976
# label값: Physalis 예측값: Physalis 12977
# label값: Physalis 예측값: Physalis 12978
# label값: Physalis 예측값: Physalis 12979
# label값: Physalis 예측값: Physalis 12980
# label값: Physalis 예측값: Physalis 12981
# label값: Physalis 예측값: Physalis 12982
# label값: Physalis 예측값: Physalis 12983
# label값: Physalis 예측값: Physalis 12984
# label값: Physalis 예측값: Physalis 12985
# label값: Physalis with Husk 예측값: Physalis with Husk 12986
# label값: Physalis with Husk 예측값: Physalis with Husk 12987
# label값: Physalis with Husk 예측값: Physalis with Husk 12988
# label값: Physalis with Husk 예측값: Physalis with Husk 12989
# label값: Physalis with Husk 예측값: Physalis with Husk 12990
# label값: Physalis with Husk 예측값: Physalis with Husk 12991
# label값: Physalis with Husk 예측값: Physalis with Husk 12992
# label값: Physalis with Husk 예측값: Physalis with Husk 12993
# label값: Physalis with Husk 예측값: Physalis with Husk 12994
# label값: Physalis with Husk 예측값: Physalis with Husk 12995
# label값: Physalis with Husk 예측값: Physalis with Husk 12996
# label값: Physalis with Husk 예측값: Physalis with Husk 12997
# label값: Physalis with Husk 예측값: Physalis with Husk 12998
# label값: Physalis with Husk 예측값: Physalis with Husk 12999
# label값: Physalis with Husk 예측값: Physalis with Husk 13000
# label값: Physalis with Husk 예측값: Physalis with Husk 13001
# label값: Physalis with Husk 예측값: Physalis with Husk 13002
# label값: Physalis with Husk 예측값: Physalis with Husk 13003
# label값: Physalis with Husk 예측값: Physalis with Husk 13004
# label값: Physalis with Husk 예측값: Physalis with Husk 13005
# label값: Physalis with Husk 예측값: Physalis with Husk 13006
# label값: Physalis with Husk 예측값: Physalis with Husk 13007
# label값: Physalis with Husk 예측값: Physalis with Husk 13008
# label값: Physalis with Husk 예측값: Physalis with Husk 13009
# label값: Physalis with Husk 예측값: Physalis with Husk 13010
# label값: Physalis with Husk 예측값: Physalis with Husk 13011
# label값: Physalis with Husk 예측값: Physalis with Husk 13012
# label값: Physalis with Husk 예측값: Physalis with Husk 13013
# label값: Physalis with Husk 예측값: Physalis with Husk 13014
# label값: Physalis with Husk 예측값: Physalis with Husk 13015
# label값: Physalis with Husk 예측값: Physalis with Husk 13016
# label값: Physalis with Husk 예측값: Physalis with Husk 13017
# label값: Physalis with Husk 예측값: Physalis with Husk 13018
# label값: Physalis with Husk 예측값: Physalis with Husk 13019
# label값: Physalis with Husk 예측값: Physalis with Husk 13020
# label값: Physalis with Husk 예측값: Physalis with Husk 13021
# label값: Physalis with Husk 예측값: Physalis with Husk 13022
# label값: Physalis with Husk 예측값: Physalis with Husk 13023
# label값: Physalis with Husk 예측값: Physalis with Husk 13024
# label값: Physalis with Husk 예측값: Physalis with Husk 13025
# label값: Physalis with Husk 예측값: Physalis with Husk 13026
# label값: Physalis with Husk 예측값: Physalis with Husk 13027
# label값: Physalis with Husk 예측값: Physalis with Husk 13028
# label값: Physalis with Husk 예측값: Physalis with Husk 13029
# label값: Physalis with Husk 예측값: Physalis with Husk 13030
# label값: Physalis with Husk 예측값: Physalis with Husk 13031
# label값: Physalis with Husk 예측값: Physalis with Husk 13032
# label값: Physalis with Husk 예측값: Physalis with Husk 13033
# label값: Physalis with Husk 예측값: Physalis with Husk 13034
# label값: Physalis with Husk 예측값: Physalis with Husk 13035
# label값: Physalis with Husk 예측값: Physalis with Husk 13036
# label값: Physalis with Husk 예측값: Physalis with Husk 13037
# label값: Physalis with Husk 예측값: Physalis with Husk 13038
# label값: Physalis with Husk 예측값: Physalis with Husk 13039
# label값: Physalis with Husk 예측값: Physalis with Husk 13040
# label값: Physalis with Husk 예측값: Physalis with Husk 13041
# label값: Physalis with Husk 예측값: Physalis with Husk 13042
# label값: Physalis with Husk 예측값: Physalis with Husk 13043
# label값: Physalis with Husk 예측값: Physalis with Husk 13044
# label값: Physalis with Husk 예측값: Physalis with Husk 13045
# label값: Physalis with Husk 예측값: Physalis with Husk 13046
# label값: Physalis with Husk 예측값: Physalis with Husk 13047
# label값: Physalis with Husk 예측값: Physalis with Husk 13048
# label값: Physalis with Husk 예측값: Physalis with Husk 13049
# label값: Physalis with Husk 예측값: Physalis with Husk 13050
# label값: Physalis with Husk 예측값: Physalis with Husk 13051
# label값: Physalis with Husk 예측값: Physalis with Husk 13052
# label값: Physalis with Husk 예측값: Physalis with Husk 13053
# label값: Physalis with Husk 예측값: Physalis with Husk 13054
# label값: Physalis with Husk 예측값: Physalis with Husk 13055
# label값: Physalis with Husk 예측값: Physalis with Husk 13056
# label값: Physalis with Husk 예측값: Physalis with Husk 13057
# label값: Physalis with Husk 예측값: Physalis with Husk 13058
# label값: Physalis with Husk 예측값: Physalis with Husk 13059
# label값: Physalis with Husk 예측값: Physalis with Husk 13060
# label값: Physalis with Husk 예측값: Physalis with Husk 13061
# label값: Physalis with Husk 예측값: Physalis with Husk 13062
# label값: Physalis with Husk 예측값: Physalis with Husk 13063
# label값: Physalis with Husk 예측값: Physalis with Husk 13064
# label값: Physalis with Husk 예측값: Physalis with Husk 13065
# label값: Physalis with Husk 예측값: Physalis with Husk 13066
# label값: Physalis with Husk 예측값: Physalis with Husk 13067
# label값: Physalis with Husk 예측값: Banana 13068
# label값: Physalis with Husk 예측값: Physalis with Husk 13069
# label값: Physalis with Husk 예측값: Physalis with Husk 13070
# label값: Physalis with Husk 예측값: Physalis with Husk 13071
# label값: Physalis with Husk 예측값: Physalis with Husk 13072
# label값: Physalis with Husk 예측값: Physalis with Husk 13073
# label값: Physalis with Husk 예측값: Physalis with Husk 13074
# label값: Physalis with Husk 예측값: Physalis with Husk 13075
# label값: Physalis with Husk 예측값: Physalis with Husk 13076
# label값: Physalis with Husk 예측값: Physalis with Husk 13077
# label값: Physalis with Husk 예측값: Physalis with Husk 13078
# label값: Physalis with Husk 예측값: Physalis with Husk 13079
# label값: Physalis with Husk 예측값: Physalis with Husk 13080
# label값: Physalis with Husk 예측값: Physalis with Husk 13081
# label값: Physalis with Husk 예측값: Physalis with Husk 13082
# label값: Physalis with Husk 예측값: Physalis with Husk 13083
# label값: Physalis with Husk 예측값: Physalis with Husk 13084
# label값: Physalis with Husk 예측값: Physalis with Husk 13085
# label값: Physalis with Husk 예측값: Physalis with Husk 13086
# label값: Physalis with Husk 예측값: Physalis with Husk 13087
# label값: Physalis with Husk 예측값: Physalis with Husk 13088
# label값: Physalis with Husk 예측값: Physalis with Husk 13089
# label값: Physalis with Husk 예측값: Physalis with Husk 13090
# label값: Physalis with Husk 예측값: Physalis with Husk 13091
# label값: Physalis with Husk 예측값: Physalis with Husk 13092
# label값: Physalis with Husk 예측값: Physalis with Husk 13093
# label값: Physalis with Husk 예측값: Physalis with Husk 13094
# label값: Physalis with Husk 예측값: Physalis with Husk 13095
# label값: Physalis with Husk 예측값: Physalis with Husk 13096
# label값: Physalis with Husk 예측값: Physalis with Husk 13097
# label값: Physalis with Husk 예측값: Physalis with Husk 13098
# label값: Physalis with Husk 예측값: Physalis with Husk 13099
# label값: Physalis with Husk 예측값: Physalis with Husk 13100
# label값: Physalis with Husk 예측값: Physalis with Husk 13101
# label값: Physalis with Husk 예측값: Physalis with Husk 13102
# label값: Physalis with Husk 예측값: Physalis with Husk 13103
# label값: Physalis with Husk 예측값: Physalis with Husk 13104
# label값: Physalis with Husk 예측값: Physalis with Husk 13105
# label값: Physalis with Husk 예측값: Physalis with Husk 13106
# label값: Physalis with Husk 예측값: Physalis with Husk 13107
# label값: Physalis with Husk 예측값: Physalis with Husk 13108
# label값: Physalis with Husk 예측값: Physalis with Husk 13109
# label값: Physalis with Husk 예측값: Physalis with Husk 13110
# label값: Physalis with Husk 예측값: Physalis with Husk 13111
# label값: Physalis with Husk 예측값: Physalis with Husk 13112
# label값: Physalis with Husk 예측값: Physalis with Husk 13113
# label값: Physalis with Husk 예측값: Physalis with Husk 13114
# label값: Physalis with Husk 예측값: Physalis with Husk 13115
# label값: Physalis with Husk 예측값: Physalis with Husk 13116
# label값: Physalis with Husk 예측값: Physalis with Husk 13117
# label값: Physalis with Husk 예측값: Physalis with Husk 13118
# label값: Physalis with Husk 예측값: Physalis with Husk 13119
# label값: Physalis with Husk 예측값: Physalis with Husk 13120
# label값: Physalis with Husk 예측값: Physalis with Husk 13121
# label값: Physalis with Husk 예측값: Physalis with Husk 13122
# label값: Physalis with Husk 예측값: Physalis with Husk 13123
# label값: Physalis with Husk 예측값: Physalis with Husk 13124
# label값: Physalis with Husk 예측값: Physalis with Husk 13125
# label값: Physalis with Husk 예측값: Physalis with Husk 13126
# label값: Physalis with Husk 예측값: Physalis with Husk 13127
# label값: Physalis with Husk 예측값: Physalis with Husk 13128
# label값: Physalis with Husk 예측값: Physalis with Husk 13129
# label값: Physalis with Husk 예측값: Physalis with Husk 13130
# label값: Physalis with Husk 예측값: Physalis with Husk 13131
# label값: Physalis with Husk 예측값: Physalis with Husk 13132
# label값: Physalis with Husk 예측값: Physalis with Husk 13133
# label값: Physalis with Husk 예측값: Physalis with Husk 13134
# label값: Physalis with Husk 예측값: Physalis with Husk 13135
# label값: Physalis with Husk 예측값: Physalis with Husk 13136
# label값: Physalis with Husk 예측값: Physalis with Husk 13137
# label값: Physalis with Husk 예측값: Physalis with Husk 13138
# label값: Physalis with Husk 예측값: Physalis with Husk 13139
# label값: Physalis with Husk 예측값: Physalis with Husk 13140
# label값: Physalis with Husk 예측값: Physalis with Husk 13141
# label값: Physalis with Husk 예측값: Physalis with Husk 13142
# label값: Physalis with Husk 예측값: Physalis with Husk 13143
# label값: Physalis with Husk 예측값: Physalis with Husk 13144
# label값: Physalis with Husk 예측값: Physalis with Husk 13145
# label값: Physalis with Husk 예측값: Physalis with Husk 13146
# label값: Physalis with Husk 예측값: Physalis with Husk 13147
# label값: Physalis with Husk 예측값: Physalis with Husk 13148
# label값: Physalis with Husk 예측값: Physalis with Husk 13149
# label값: Pineapple 예측값: Pineapple 13150
# label값: Pineapple 예측값: Pineapple 13151
# label값: Pineapple 예측값: Pineapple 13152
# label값: Pineapple 예측값: Pineapple 13153
# label값: Pineapple 예측값: Pineapple 13154
# label값: Pineapple 예측값: Pineapple 13155
# label값: Pineapple 예측값: Pineapple 13156
# label값: Pineapple 예측값: Pineapple 13157
# label값: Pineapple 예측값: Pineapple 13158
# label값: Pineapple 예측값: Pineapple 13159
# label값: Pineapple 예측값: Pineapple 13160
# label값: Pineapple 예측값: Pineapple 13161
# label값: Pineapple 예측값: Pineapple 13162
# label값: Pineapple 예측값: Pineapple 13163
# label값: Pineapple 예측값: Pineapple 13164
# label값: Pineapple 예측값: Pineapple 13165
# label값: Pineapple 예측값: Pineapple 13166
# label값: Pineapple 예측값: Pineapple 13167
# label값: Pineapple 예측값: Pineapple 13168
# label값: Pineapple 예측값: Pineapple 13169
# label값: Pineapple 예측값: Pineapple 13170
# label값: Pineapple 예측값: Pineapple 13171
# label값: Pineapple 예측값: Pineapple 13172
# label값: Pineapple 예측값: Pineapple 13173
# label값: Pineapple 예측값: Pineapple 13174
# label값: Pineapple 예측값: Pineapple 13175
# label값: Pineapple 예측값: Pineapple 13176
# label값: Pineapple 예측값: Pineapple 13177
# label값: Pineapple 예측값: Pineapple 13178
# label값: Pineapple 예측값: Pineapple 13179
# label값: Pineapple 예측값: Pineapple 13180
# label값: Pineapple 예측값: Pineapple 13181
# label값: Pineapple 예측값: Pineapple 13182
# label값: Pineapple 예측값: Pineapple 13183
# label값: Pineapple 예측값: Pineapple 13184
# label값: Pineapple 예측값: Pineapple 13185
# label값: Pineapple 예측값: Pineapple 13186
# label값: Pineapple 예측값: Pineapple 13187
# label값: Pineapple 예측값: Pineapple 13188
# label값: Pineapple 예측값: Pineapple 13189
# label값: Pineapple 예측값: Pineapple 13190
# label값: Pineapple 예측값: Pineapple 13191
# label값: Pineapple 예측값: Pineapple 13192
# label값: Pineapple 예측값: Pineapple 13193
# label값: Pineapple 예측값: Pineapple 13194
# label값: Pineapple 예측값: Pineapple 13195
# label값: Pineapple 예측값: Pineapple 13196
# label값: Pineapple 예측값: Pineapple 13197
# label값: Pineapple 예측값: Pineapple 13198
# label값: Pineapple 예측값: Pineapple 13199
# label값: Pineapple 예측값: Pineapple 13200
# label값: Pineapple 예측값: Pineapple 13201
# label값: Pineapple 예측값: Pineapple 13202
# label값: Pineapple 예측값: Pineapple 13203
# label값: Pineapple 예측값: Pineapple 13204
# label값: Pineapple 예측값: Pineapple 13205
# label값: Pineapple 예측값: Pineapple 13206
# label값: Pineapple 예측값: Pineapple 13207
# label값: Pineapple 예측값: Pineapple 13208
# label값: Pineapple 예측값: Pineapple 13209
# label값: Pineapple 예측값: Pineapple 13210
# label값: Pineapple 예측값: Pineapple 13211
# label값: Pineapple 예측값: Pineapple 13212
# label값: Pineapple 예측값: Pineapple 13213
# label값: Pineapple 예측값: Pineapple 13214
# label값: Pineapple 예측값: Pineapple 13215
# label값: Pineapple 예측값: Pineapple 13216
# label값: Pineapple 예측값: Pineapple 13217
# label값: Pineapple 예측값: Pineapple 13218
# label값: Pineapple 예측값: Pineapple 13219
# label값: Pineapple 예측값: Pineapple 13220
# label값: Pineapple 예측값: Pineapple 13221
# label값: Pineapple 예측값: Pineapple 13222
# label값: Pineapple 예측값: Pineapple 13223
# label값: Pineapple 예측값: Pineapple 13224
# label값: Pineapple 예측값: Pineapple 13225
# label값: Pineapple 예측값: Pineapple 13226
# label값: Pineapple 예측값: Pineapple 13227
# label값: Pineapple 예측값: Pineapple 13228
# label값: Pineapple 예측값: Pineapple 13229
# label값: Pineapple 예측값: Pineapple 13230
# label값: Pineapple 예측값: Pineapple 13231
# label값: Pineapple 예측값: Pineapple 13232
# label값: Pineapple 예측값: Pineapple 13233
# label값: Pineapple 예측값: Pineapple 13234
# label값: Pineapple 예측값: Pineapple 13235
# label값: Pineapple 예측값: Pineapple 13236
# label값: Pineapple 예측값: Pineapple 13237
# label값: Pineapple 예측값: Pineapple 13238
# label값: Pineapple 예측값: Pineapple 13239
# label값: Pineapple 예측값: Pineapple 13240
# label값: Pineapple 예측값: Pineapple 13241
# label값: Pineapple 예측값: Pineapple 13242
# label값: Pineapple 예측값: Pineapple 13243
# label값: Pineapple 예측값: Pineapple 13244
# label값: Pineapple 예측값: Pineapple 13245
# label값: Pineapple 예측값: Pineapple 13246
# label값: Pineapple 예측값: Pineapple 13247
# label값: Pineapple 예측값: Pineapple 13248
# label값: Pineapple 예측값: Pineapple 13249
# label값: Pineapple 예측값: Pineapple 13250
# label값: Pineapple 예측값: Pineapple 13251
# label값: Pineapple 예측값: Pineapple 13252
# label값: Pineapple 예측값: Pineapple 13253
# label값: Pineapple 예측값: Pineapple 13254
# label값: Pineapple 예측값: Pineapple 13255
# label값: Pineapple 예측값: Pineapple 13256
# label값: Pineapple 예측값: Pineapple 13257
# label값: Pineapple 예측값: Pineapple 13258
# label값: Pineapple 예측값: Pineapple 13259
# label값: Pineapple 예측값: Pineapple 13260
# label값: Pineapple 예측값: Pineapple 13261
# label값: Pineapple 예측값: Pineapple 13262
# label값: Pineapple 예측값: Pineapple 13263
# label값: Pineapple 예측값: Pineapple 13264
# label값: Pineapple 예측값: Pineapple 13265
# label값: Pineapple 예측값: Pineapple 13266
# label값: Pineapple 예측값: Pineapple 13267
# label값: Pineapple 예측값: Pineapple 13268
# label값: Pineapple 예측값: Pineapple 13269
# label값: Pineapple 예측값: Pineapple 13270
# label값: Pineapple 예측값: Pineapple 13271
# label값: Pineapple 예측값: Pineapple 13272
# label값: Pineapple 예측값: Pineapple 13273
# label값: Pineapple 예측값: Pineapple 13274
# label값: Pineapple 예측값: Pineapple 13275
# label값: Pineapple 예측값: Pineapple 13276
# label값: Pineapple 예측값: Pineapple 13277
# label값: Pineapple 예측값: Pineapple 13278
# label값: Pineapple 예측값: Pineapple 13279
# label값: Pineapple 예측값: Pineapple 13280
# label값: Pineapple 예측값: Pineapple 13281
# label값: Pineapple 예측값: Pineapple 13282
# label값: Pineapple 예측값: Pineapple 13283
# label값: Pineapple 예측값: Pineapple 13284
# label값: Pineapple 예측값: Pineapple 13285
# label값: Pineapple 예측값: Pineapple 13286
# label값: Pineapple 예측값: Pineapple 13287
# label값: Pineapple 예측값: Pineapple 13288
# label값: Pineapple 예측값: Pineapple 13289
# label값: Pineapple 예측값: Pineapple 13290
# label값: Pineapple 예측값: Pineapple 13291
# label값: Pineapple 예측값: Pineapple 13292
# label값: Pineapple 예측값: Pineapple 13293
# label값: Pineapple 예측값: Pineapple 13294
# label값: Pineapple 예측값: Pineapple 13295
# label값: Pineapple 예측값: Pineapple 13296
# label값: Pineapple 예측값: Pineapple 13297
# label값: Pineapple 예측값: Pineapple 13298
# label값: Pineapple 예측값: Pineapple 13299
# label값: Pineapple 예측값: Pineapple 13300
# label값: Pineapple 예측값: Pineapple 13301
# label값: Pineapple 예측값: Pineapple 13302
# label값: Pineapple 예측값: Pineapple 13303
# label값: Pineapple 예측값: Pineapple 13304
# label값: Pineapple 예측값: Pineapple 13305
# label값: Pineapple 예측값: Pineapple 13306
# label값: Pineapple 예측값: Pineapple 13307
# label값: Pineapple 예측값: Pineapple 13308
# label값: Pineapple 예측값: Pineapple 13309
# label값: Pineapple 예측값: Pineapple 13310
# label값: Pineapple 예측값: Pineapple 13311
# label값: Pineapple 예측값: Pineapple 13312
# label값: Pineapple 예측값: Pineapple 13313
# label값: Pineapple 예측값: Pineapple 13314
# label값: Pineapple 예측값: Pineapple 13315
# label값: Pineapple Mini 예측값: Pineapple Mini 13316
# label값: Pineapple Mini 예측값: Pineapple Mini 13317
# label값: Pineapple Mini 예측값: Pineapple Mini 13318
# label값: Pineapple Mini 예측값: Pineapple Mini 13319
# label값: Pineapple Mini 예측값: Pineapple Mini 13320
# label값: Pineapple Mini 예측값: Pineapple Mini 13321
# label값: Pineapple Mini 예측값: Pineapple Mini 13322
# label값: Pineapple Mini 예측값: Pineapple Mini 13323
# label값: Pineapple Mini 예측값: Pineapple Mini 13324
# label값: Pineapple Mini 예측값: Pineapple Mini 13325
# label값: Pineapple Mini 예측값: Pineapple Mini 13326
# label값: Pineapple Mini 예측값: Pineapple Mini 13327
# label값: Pineapple Mini 예측값: Pineapple Mini 13328
# label값: Pineapple Mini 예측값: Pineapple Mini 13329
# label값: Pineapple Mini 예측값: Pineapple Mini 13330
# label값: Pineapple Mini 예측값: Pineapple Mini 13331
# label값: Pineapple Mini 예측값: Pineapple Mini 13332
# label값: Pineapple Mini 예측값: Pineapple Mini 13333
# label값: Pineapple Mini 예측값: Pineapple Mini 13334
# label값: Pineapple Mini 예측값: Pineapple Mini 13335
# label값: Pineapple Mini 예측값: Pineapple Mini 13336
# label값: Pineapple Mini 예측값: Pineapple Mini 13337
# label값: Pineapple Mini 예측값: Pineapple Mini 13338
# label값: Pineapple Mini 예측값: Pineapple Mini 13339
# label값: Pineapple Mini 예측값: Pineapple Mini 13340
# label값: Pineapple Mini 예측값: Pineapple Mini 13341
# label값: Pineapple Mini 예측값: Pineapple Mini 13342
# label값: Pineapple Mini 예측값: Pineapple Mini 13343
# label값: Pineapple Mini 예측값: Pineapple Mini 13344
# label값: Pineapple Mini 예측값: Pineapple Mini 13345
# label값: Pineapple Mini 예측값: Pineapple Mini 13346
# label값: Pineapple Mini 예측값: Pineapple Mini 13347
# label값: Pineapple Mini 예측값: Pineapple Mini 13348
# label값: Pineapple Mini 예측값: Pineapple Mini 13349
# label값: Pineapple Mini 예측값: Pineapple Mini 13350
# label값: Pineapple Mini 예측값: Pineapple Mini 13351
# label값: Pineapple Mini 예측값: Pineapple Mini 13352
# label값: Pineapple Mini 예측값: Pineapple Mini 13353
# label값: Pineapple Mini 예측값: Pineapple Mini 13354
# label값: Pineapple Mini 예측값: Pineapple Mini 13355
# label값: Pineapple Mini 예측값: Pineapple Mini 13356
# label값: Pineapple Mini 예측값: Pineapple Mini 13357
# label값: Pineapple Mini 예측값: Pineapple Mini 13358
# label값: Pineapple Mini 예측값: Pineapple Mini 13359
# label값: Pineapple Mini 예측값: Pineapple Mini 13360
# label값: Pineapple Mini 예측값: Pineapple Mini 13361
# label값: Pineapple Mini 예측값: Pineapple Mini 13362
# label값: Pineapple Mini 예측값: Pineapple Mini 13363
# label값: Pineapple Mini 예측값: Pineapple Mini 13364
# label값: Pineapple Mini 예측값: Pineapple Mini 13365
# label값: Pineapple Mini 예측값: Pineapple Mini 13366
# label값: Pineapple Mini 예측값: Pineapple Mini 13367
# label값: Pineapple Mini 예측값: Pineapple Mini 13368
# label값: Pineapple Mini 예측값: Pineapple Mini 13369
# label값: Pineapple Mini 예측값: Pineapple Mini 13370
# label값: Pineapple Mini 예측값: Pineapple Mini 13371
# label값: Pineapple Mini 예측값: Pineapple Mini 13372
# label값: Pineapple Mini 예측값: Pineapple Mini 13373
# label값: Pineapple Mini 예측값: Pineapple Mini 13374
# label값: Pineapple Mini 예측값: Pineapple Mini 13375
# label값: Pineapple Mini 예측값: Pineapple Mini 13376
# label값: Pineapple Mini 예측값: Pineapple Mini 13377
# label값: Pineapple Mini 예측값: Pineapple Mini 13378
# label값: Pineapple Mini 예측값: Pineapple Mini 13379
# label값: Pineapple Mini 예측값: Pineapple Mini 13380
# label값: Pineapple Mini 예측값: Pineapple Mini 13381
# label값: Pineapple Mini 예측값: Pineapple Mini 13382
# label값: Pineapple Mini 예측값: Pineapple Mini 13383
# label값: Pineapple Mini 예측값: Pineapple Mini 13384
# label값: Pineapple Mini 예측값: Pineapple Mini 13385
# label값: Pineapple Mini 예측값: Pineapple Mini 13386
# label값: Pineapple Mini 예측값: Pineapple Mini 13387
# label값: Pineapple Mini 예측값: Pineapple Mini 13388
# label값: Pineapple Mini 예측값: Pineapple Mini 13389
# label값: Pineapple Mini 예측값: Pineapple Mini 13390
# label값: Pineapple Mini 예측값: Pineapple Mini 13391
# label값: Pineapple Mini 예측값: Pineapple Mini 13392
# label값: Pineapple Mini 예측값: Pineapple Mini 13393
# label값: Pineapple Mini 예측값: Pineapple Mini 13394
# label값: Pineapple Mini 예측값: Pineapple Mini 13395
# label값: Pineapple Mini 예측값: Pineapple Mini 13396
# label값: Pineapple Mini 예측값: Pineapple Mini 13397
# label값: Pineapple Mini 예측값: Pineapple Mini 13398
# label값: Pineapple Mini 예측값: Pineapple Mini 13399
# label값: Pineapple Mini 예측값: Pineapple Mini 13400
# label값: Pineapple Mini 예측값: Pineapple Mini 13401
# label값: Pineapple Mini 예측값: Pineapple Mini 13402
# label값: Pineapple Mini 예측값: Pineapple Mini 13403
# label값: Pineapple Mini 예측값: Pineapple Mini 13404
# label값: Pineapple Mini 예측값: Pineapple Mini 13405
# label값: Pineapple Mini 예측값: Pineapple Mini 13406
# label값: Pineapple Mini 예측값: Pineapple Mini 13407
# label값: Pineapple Mini 예측값: Pineapple Mini 13408
# label값: Pineapple Mini 예측값: Pineapple Mini 13409
# label값: Pineapple Mini 예측값: Pineapple Mini 13410
# label값: Pineapple Mini 예측값: Pineapple Mini 13411
# label값: Pineapple Mini 예측값: Pineapple Mini 13412
# label값: Pineapple Mini 예측값: Pineapple Mini 13413
# label값: Pineapple Mini 예측값: Pineapple Mini 13414
# label값: Pineapple Mini 예측값: Pineapple Mini 13415
# label값: Pineapple Mini 예측값: Pineapple Mini 13416
# label값: Pineapple Mini 예측값: Pineapple Mini 13417
# label값: Pineapple Mini 예측값: Pineapple Mini 13418
# label값: Pineapple Mini 예측값: Pineapple Mini 13419
# label값: Pineapple Mini 예측값: Pineapple Mini 13420
# label값: Pineapple Mini 예측값: Pineapple Mini 13421
# label값: Pineapple Mini 예측값: Pineapple Mini 13422
# label값: Pineapple Mini 예측값: Pineapple Mini 13423
# label값: Pineapple Mini 예측값: Pineapple Mini 13424
# label값: Pineapple Mini 예측값: Pineapple Mini 13425
# label값: Pineapple Mini 예측값: Pineapple Mini 13426
# label값: Pineapple Mini 예측값: Pineapple Mini 13427
# label값: Pineapple Mini 예측값: Pineapple Mini 13428
# label값: Pineapple Mini 예측값: Pineapple Mini 13429
# label값: Pineapple Mini 예측값: Pineapple Mini 13430
# label값: Pineapple Mini 예측값: Pineapple Mini 13431
# label값: Pineapple Mini 예측값: Pineapple Mini 13432
# label값: Pineapple Mini 예측값: Pineapple Mini 13433
# label값: Pineapple Mini 예측값: Pineapple Mini 13434
# label값: Pineapple Mini 예측값: Pineapple Mini 13435
# label값: Pineapple Mini 예측값: Pineapple Mini 13436
# label값: Pineapple Mini 예측값: Pineapple Mini 13437
# label값: Pineapple Mini 예측값: Pineapple Mini 13438
# label값: Pineapple Mini 예측값: Pineapple Mini 13439
# label값: Pineapple Mini 예측값: Pineapple Mini 13440
# label값: Pineapple Mini 예측값: Pineapple Mini 13441
# label값: Pineapple Mini 예측값: Pineapple Mini 13442
# label값: Pineapple Mini 예측값: Pineapple Mini 13443
# label값: Pineapple Mini 예측값: Pineapple Mini 13444
# label값: Pineapple Mini 예측값: Pineapple Mini 13445
# label값: Pineapple Mini 예측값: Pineapple Mini 13446
# label값: Pineapple Mini 예측값: Pineapple Mini 13447
# label값: Pineapple Mini 예측값: Pineapple Mini 13448
# label값: Pineapple Mini 예측값: Pineapple Mini 13449
# label값: Pineapple Mini 예측값: Pineapple Mini 13450
# label값: Pineapple Mini 예측값: Pineapple Mini 13451
# label값: Pineapple Mini 예측값: Pineapple Mini 13452
# label값: Pineapple Mini 예측값: Pineapple Mini 13453
# label값: Pineapple Mini 예측값: Pineapple Mini 13454
# label값: Pineapple Mini 예측값: Pineapple Mini 13455
# label값: Pineapple Mini 예측값: Pineapple Mini 13456
# label값: Pineapple Mini 예측값: Pineapple Mini 13457
# label값: Pineapple Mini 예측값: Pineapple Mini 13458
# label값: Pineapple Mini 예측값: Pineapple Mini 13459
# label값: Pineapple Mini 예측값: Pineapple Mini 13460
# label값: Pineapple Mini 예측값: Pineapple Mini 13461
# label값: Pineapple Mini 예측값: Pineapple Mini 13462
# label값: Pineapple Mini 예측값: Pineapple Mini 13463
# label값: Pineapple Mini 예측값: Pineapple Mini 13464
# label값: Pineapple Mini 예측값: Pineapple Mini 13465
# label값: Pineapple Mini 예측값: Pineapple Mini 13466
# label값: Pineapple Mini 예측값: Pineapple Mini 13467
# label값: Pineapple Mini 예측값: Pineapple Mini 13468
# label값: Pineapple Mini 예측값: Pineapple Mini 13469
# label값: Pineapple Mini 예측값: Pineapple Mini 13470
# label값: Pineapple Mini 예측값: Pineapple Mini 13471
# label값: Pineapple Mini 예측값: Pineapple Mini 13472
# label값: Pineapple Mini 예측값: Pineapple Mini 13473
# label값: Pineapple Mini 예측값: Pineapple Mini 13474
# label값: Pineapple Mini 예측값: Pineapple Mini 13475
# label값: Pineapple Mini 예측값: Pineapple Mini 13476
# label값: Pineapple Mini 예측값: Pineapple Mini 13477
# label값: Pineapple Mini 예측값: Pineapple Mini 13478
# label값: Pitahaya Red 예측값: Pitahaya Red 13479
# label값: Pitahaya Red 예측값: Pitahaya Red 13480
# label값: Pitahaya Red 예측값: Pitahaya Red 13481
# label값: Pitahaya Red 예측값: Pitahaya Red 13482
# label값: Pitahaya Red 예측값: Pitahaya Red 13483
# label값: Pitahaya Red 예측값: Pitahaya Red 13484
# label값: Pitahaya Red 예측값: Pitahaya Red 13485
# label값: Pitahaya Red 예측값: Pitahaya Red 13486
# label값: Pitahaya Red 예측값: Pitahaya Red 13487
# label값: Pitahaya Red 예측값: Pitahaya Red 13488
# label값: Pitahaya Red 예측값: Pitahaya Red 13489
# label값: Pitahaya Red 예측값: Pitahaya Red 13490
# label값: Pitahaya Red 예측값: Pitahaya Red 13491
# label값: Pitahaya Red 예측값: Pitahaya Red 13492
# label값: Pitahaya Red 예측값: Pitahaya Red 13493
# label값: Pitahaya Red 예측값: Pitahaya Red 13494
# label값: Pitahaya Red 예측값: Pitahaya Red 13495
# label값: Pitahaya Red 예측값: Pitahaya Red 13496
# label값: Pitahaya Red 예측값: Pitahaya Red 13497
# label값: Pitahaya Red 예측값: Pitahaya Red 13498
# label값: Pitahaya Red 예측값: Pitahaya Red 13499
# label값: Pitahaya Red 예측값: Pitahaya Red 13500
# label값: Pitahaya Red 예측값: Pitahaya Red 13501
# label값: Pitahaya Red 예측값: Pitahaya Red 13502
# label값: Pitahaya Red 예측값: Pitahaya Red 13503
# label값: Pitahaya Red 예측값: Pitahaya Red 13504
# label값: Pitahaya Red 예측값: Pitahaya Red 13505
# label값: Pitahaya Red 예측값: Pitahaya Red 13506
# label값: Pitahaya Red 예측값: Pitahaya Red 13507
# label값: Pitahaya Red 예측값: Pitahaya Red 13508
# label값: Pitahaya Red 예측값: Pitahaya Red 13509
# label값: Pitahaya Red 예측값: Pitahaya Red 13510
# label값: Pitahaya Red 예측값: Pitahaya Red 13511
# label값: Pitahaya Red 예측값: Pitahaya Red 13512
# label값: Pitahaya Red 예측값: Pitahaya Red 13513
# label값: Pitahaya Red 예측값: Pitahaya Red 13514
# label값: Pitahaya Red 예측값: Pitahaya Red 13515
# label값: Pitahaya Red 예측값: Pitahaya Red 13516
# label값: Pitahaya Red 예측값: Pitahaya Red 13517
# label값: Pitahaya Red 예측값: Pitahaya Red 13518
# label값: Pitahaya Red 예측값: Pitahaya Red 13519
# label값: Pitahaya Red 예측값: Pitahaya Red 13520
# label값: Pitahaya Red 예측값: Pitahaya Red 13521
# label값: Pitahaya Red 예측값: Pitahaya Red 13522
# label값: Pitahaya Red 예측값: Pitahaya Red 13523
# label값: Pitahaya Red 예측값: Pitahaya Red 13524
# label값: Pitahaya Red 예측값: Pitahaya Red 13525
# label값: Pitahaya Red 예측값: Pitahaya Red 13526
# label값: Pitahaya Red 예측값: Pitahaya Red 13527
# label값: Pitahaya Red 예측값: Pitahaya Red 13528
# label값: Pitahaya Red 예측값: Pitahaya Red 13529
# label값: Pitahaya Red 예측값: Pitahaya Red 13530
# label값: Pitahaya Red 예측값: Pitahaya Red 13531
# label값: Pitahaya Red 예측값: Pitahaya Red 13532
# label값: Pitahaya Red 예측값: Pitahaya Red 13533
# label값: Pitahaya Red 예측값: Pitahaya Red 13534
# label값: Pitahaya Red 예측값: Pitahaya Red 13535
# label값: Pitahaya Red 예측값: Pitahaya Red 13536
# label값: Pitahaya Red 예측값: Pitahaya Red 13537
# label값: Pitahaya Red 예측값: Pitahaya Red 13538
# label값: Pitahaya Red 예측값: Pitahaya Red 13539
# label값: Pitahaya Red 예측값: Pitahaya Red 13540
# label값: Pitahaya Red 예측값: Pitahaya Red 13541
# label값: Pitahaya Red 예측값: Pitahaya Red 13542
# label값: Pitahaya Red 예측값: Pitahaya Red 13543
# label값: Pitahaya Red 예측값: Pitahaya Red 13544
# label값: Pitahaya Red 예측값: Pitahaya Red 13545
# label값: Pitahaya Red 예측값: Pitahaya Red 13546
# label값: Pitahaya Red 예측값: Pitahaya Red 13547
# label값: Pitahaya Red 예측값: Pitahaya Red 13548
# label값: Pitahaya Red 예측값: Pitahaya Red 13549
# label값: Pitahaya Red 예측값: Pitahaya Red 13550
# label값: Pitahaya Red 예측값: Pitahaya Red 13551
# label값: Pitahaya Red 예측값: Pitahaya Red 13552
# label값: Pitahaya Red 예측값: Pitahaya Red 13553
# label값: Pitahaya Red 예측값: Pitahaya Red 13554
# label값: Pitahaya Red 예측값: Pitahaya Red 13555
# label값: Pitahaya Red 예측값: Pitahaya Red 13556
# label값: Pitahaya Red 예측값: Pitahaya Red 13557
# label값: Pitahaya Red 예측값: Pitahaya Red 13558
# label값: Pitahaya Red 예측값: Pitahaya Red 13559
# label값: Pitahaya Red 예측값: Pitahaya Red 13560
# label값: Pitahaya Red 예측값: Pitahaya Red 13561
# label값: Pitahaya Red 예측값: Pitahaya Red 13562
# label값: Pitahaya Red 예측값: Pitahaya Red 13563
# label값: Pitahaya Red 예측값: Pitahaya Red 13564
# label값: Pitahaya Red 예측값: Pitahaya Red 13565
# label값: Pitahaya Red 예측값: Pitahaya Red 13566
# label값: Pitahaya Red 예측값: Pitahaya Red 13567
# label값: Pitahaya Red 예측값: Pitahaya Red 13568
# label값: Pitahaya Red 예측값: Pitahaya Red 13569
# label값: Pitahaya Red 예측값: Pitahaya Red 13570
# label값: Pitahaya Red 예측값: Pitahaya Red 13571
# label값: Pitahaya Red 예측값: Pitahaya Red 13572
# label값: Pitahaya Red 예측값: Pitahaya Red 13573
# label값: Pitahaya Red 예측값: Pitahaya Red 13574
# label값: Pitahaya Red 예측값: Pitahaya Red 13575
# label값: Pitahaya Red 예측값: Pitahaya Red 13576
# label값: Pitahaya Red 예측값: Pitahaya Red 13577
# label값: Pitahaya Red 예측값: Pitahaya Red 13578
# label값: Pitahaya Red 예측값: Pitahaya Red 13579
# label값: Pitahaya Red 예측값: Pitahaya Red 13580
# label값: Pitahaya Red 예측값: Pitahaya Red 13581
# label값: Pitahaya Red 예측값: Pitahaya Red 13582
# label값: Pitahaya Red 예측값: Pitahaya Red 13583
# label값: Pitahaya Red 예측값: Pitahaya Red 13584
# label값: Pitahaya Red 예측값: Pitahaya Red 13585
# label값: Pitahaya Red 예측값: Pitahaya Red 13586
# label값: Pitahaya Red 예측값: Pitahaya Red 13587
# label값: Pitahaya Red 예측값: Pitahaya Red 13588
# label값: Pitahaya Red 예측값: Pitahaya Red 13589
# label값: Pitahaya Red 예측값: Pitahaya Red 13590
# label값: Pitahaya Red 예측값: Pitahaya Red 13591
# label값: Pitahaya Red 예측값: Pitahaya Red 13592
# label값: Pitahaya Red 예측값: Pitahaya Red 13593
# ...
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17132
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17133
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17134
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17135
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17136
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17137
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17138
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17139
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17140
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17141
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17142
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17143
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17144
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17145
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17146
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17147
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17148
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17149
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17150
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17151
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17152
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17153
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17154
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17155
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17156
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17157
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17158
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17159
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17160
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17161
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17162
# label값: Tomato Cherry Red 예측값: Tomato Cherry Red 17163
# label값: Tomato Maroon 예측값: Tomato Maroon 17164
# label값: Tomato Maroon 예측값: Tomato Maroon 17165
# label값: Tomato Maroon 예측값: Tomato Maroon 17166
# label값: Tomato Maroon 예측값: Tomato Maroon 17167
# label값: Tomato Maroon 예측값: Tomato Maroon 17168
# label값: Tomato Maroon 예측값: Tomato Maroon 17169
# label값: Tomato Maroon 예측값: Tomato Maroon 17170
# label값: Tomato Maroon 예측값: Tomato Maroon 17171
# label값: Tomato Maroon 예측값: Tomato Maroon 17172
# label값: Tomato Maroon 예측값: Tomato Maroon 17173
# label값: Tomato Maroon 예측값: Tomato Maroon 17174
# label값: Tomato Maroon 예측값: Tomato Maroon 17175
# label값: Tomato Maroon 예측값: Tomato Maroon 17176
# label값: Tomato Maroon 예측값: Tomato Maroon 17177
# label값: Tomato Maroon 예측값: Tomato Maroon 17178
# label값: Tomato Maroon 예측값: Tomato Maroon 17179
# label값: Tomato Maroon 예측값: Tomato Maroon 17180
# label값: Tomato Maroon 예측값: Tomato Maroon 17181
# label값: Tomato Maroon 예측값: Tomato Maroon 17182
# label값: Tomato Maroon 예측값: Tomato Maroon 17183
# label값: Tomato Maroon 예측값: Tomato Maroon 17184
# label값: Tomato Maroon 예측값: Tomato Maroon 17185
# label값: Tomato Maroon 예측값: Tomato Maroon 17186
# label값: Tomato Maroon 예측값: Tomato Maroon 17187
# label값: Tomato Maroon 예측값: Tomato Maroon 17188
# label값: Tomato Maroon 예측값: Tomato Maroon 17189
# label값: Tomato Maroon 예측값: Tomato Maroon 17190
# label값: Tomato Maroon 예측값: Tomato Maroon 17191
# label값: Tomato Maroon 예측값: Tomato Maroon 17192
# label값: Tomato Maroon 예측값: Tomato Maroon 17193
# label값: Tomato Maroon 예측값: Tomato Maroon 17194
# label값: Tomato Maroon 예측값: Tomato Maroon 17195
# label값: Tomato Maroon 예측값: Tomato Maroon 17196
# label값: Tomato Maroon 예측값: Tomato Maroon 17197
# label값: Tomato Maroon 예측값: Tomato Maroon 17198
# label값: Tomato Maroon 예측값: Tomato Maroon 17199
# label값: Tomato Maroon 예측값: Tomato Maroon 17200
# label값: Tomato Maroon 예측값: Tomato Maroon 17201
# label값: Tomato Maroon 예측값: Tomato Maroon 17202
# label값: Tomato Maroon 예측값: Tomato Maroon 17203
# label값: Tomato Maroon 예측값: Tomato Maroon 17204
# label값: Tomato Maroon 예측값: Tomato Maroon 17205
# label값: Tomato Maroon 예측값: Tomato Maroon 17206
# label값: Tomato Maroon 예측값: Tomato Maroon 17207
# label값: Tomato Maroon 예측값: Tomato Maroon 17208
# label값: Tomato Maroon 예측값: Tomato Maroon 17209
# label값: Tomato Maroon 예측값: Tomato Maroon 17210
# label값: Tomato Maroon 예측값: Tomato Maroon 17211
# label값: Tomato Maroon 예측값: Tomato Maroon 17212
# label값: Tomato Maroon 예측값: Tomato Maroon 17213
# label값: Tomato Maroon 예측값: Tomato Maroon 17214
# label값: Tomato Maroon 예측값: Tomato Maroon 17215
# label값: Tomato Maroon 예측값: Tomato Maroon 17216
# label값: Tomato Maroon 예측값: Tomato Maroon 17217
# label값: Tomato Maroon 예측값: Tomato Maroon 17218
# label값: Tomato Maroon 예측값: Tomato Maroon 17219
# label값: Tomato Maroon 예측값: Tomato Maroon 17220
# label값: Tomato Maroon 예측값: Tomato Maroon 17221
# label값: Tomato Maroon 예측값: Tomato Maroon 17222
# label값: Tomato Maroon 예측값: Tomato Maroon 17223
# label값: Tomato Maroon 예측값: Tomato Maroon 17224
# label값: Tomato Maroon 예측값: Tomato Maroon 17225
# label값: Tomato Maroon 예측값: Tomato Maroon 17226
# label값: Tomato Maroon 예측값: Tomato Maroon 17227
# label값: Tomato Maroon 예측값: Tomato Maroon 17228
# label값: Tomato Maroon 예측값: Tomato Maroon 17229
# label값: Tomato Maroon 예측값: Tomato Maroon 17230
# label값: Tomato Maroon 예측값: Tomato Maroon 17231
# label값: Tomato Maroon 예측값: Tomato Maroon 17232
# label값: Tomato Maroon 예측값: Tomato Maroon 17233
# label값: Tomato Maroon 예측값: Tomato Maroon 17234
# label값: Tomato Maroon 예측값: Tomato Maroon 17235
# label값: Tomato Maroon 예측값: Tomato Maroon 17236
# label값: Tomato Maroon 예측값: Tomato Maroon 17237
# label값: Tomato Maroon 예측값: Tomato Maroon 17238
# label값: Tomato Maroon 예측값: Tomato Maroon 17239
# label값: Tomato Maroon 예측값: Tomato Maroon 17240
# label값: Tomato Maroon 예측값: Tomato Maroon 17241
# label값: Tomato Maroon 예측값: Tomato Maroon 17242
# label값: Tomato Maroon 예측값: Tomato Maroon 17243
# label값: Tomato Maroon 예측값: Tomato Maroon 17244
# label값: Tomato Maroon 예측값: Tomato Maroon 17245
# label값: Tomato Maroon 예측값: Tomato Maroon 17246
# label값: Tomato Maroon 예측값: Tomato Maroon 17247
# label값: Tomato Maroon 예측값: Tomato Maroon 17248
# label값: Tomato Maroon 예측값: Tomato Maroon 17249
# label값: Tomato Maroon 예측값: Tomato Maroon 17250
# label값: Tomato Maroon 예측값: Tomato Maroon 17251
# label값: Tomato Maroon 예측값: Tomato Maroon 17252
# label값: Tomato Maroon 예측값: Tomato Maroon 17253
# label값: Tomato Maroon 예측값: Tomato Maroon 17254
# label값: Tomato Maroon 예측값: Tomato Maroon 17255
# label값: Tomato Maroon 예측값: Tomato Maroon 17256
# label값: Tomato Maroon 예측값: Tomato Maroon 17257
# label값: Tomato Maroon 예측값: Tomato Maroon 17258
# label값: Tomato Maroon 예측값: Tomato Maroon 17259
# label값: Tomato Maroon 예측값: Tomato Maroon 17260
# label값: Tomato Maroon 예측값: Tomato Maroon 17261
# label값: Tomato Maroon 예측값: Tomato Maroon 17262
# label값: Tomato Maroon 예측값: Tomato Maroon 17263
# label값: Tomato Maroon 예측값: Tomato Maroon 17264
# label값: Tomato Maroon 예측값: Tomato Maroon 17265
# label값: Tomato Maroon 예측값: Tomato Maroon 17266
# label값: Tomato Maroon 예측값: Tomato Maroon 17267
# label값: Tomato Maroon 예측값: Tomato Maroon 17268
# label값: Tomato Maroon 예측값: Tomato Maroon 17269
# label값: Tomato Maroon 예측값: Tomato Maroon 17270
# label값: Tomato Maroon 예측값: Tomato Maroon 17271
# label값: Tomato Maroon 예측값: Tomato Maroon 17272
# label값: Tomato Maroon 예측값: Tomato Maroon 17273
# label값: Tomato Maroon 예측값: Tomato Maroon 17274
# label값: Tomato Maroon 예측값: Tomato Maroon 17275
# label값: Tomato Maroon 예측값: Tomato Maroon 17276
# label값: Tomato Maroon 예측값: Tomato Maroon 17277
# label값: Tomato Maroon 예측값: Tomato Maroon 17278
# label값: Tomato Maroon 예측값: Tomato Maroon 17279
# label값: Tomato Maroon 예측값: Tomato Maroon 17280
# label값: Tomato Maroon 예측값: Tomato Maroon 17281
# label값: Tomato Maroon 예측값: Tomato Maroon 17282
# label값: Tomato Maroon 예측값: Tomato Maroon 17283
# label값: Tomato Maroon 예측값: Tomato Maroon 17284
# label값: Tomato Maroon 예측값: Tomato Maroon 17285
# label값: Tomato Maroon 예측값: Tomato Maroon 17286
# label값: Tomato Maroon 예측값: Tomato Maroon 17287
# label값: Tomato Maroon 예측값: Tomato Maroon 17288
# label값: Tomato Maroon 예측값: Tomato Maroon 17289
# label값: Tomato Maroon 예측값: Tomato Maroon 17290
# label값: Walnut 예측값: Walnut 17291
# label값: Walnut 예측값: Walnut 17292
# label값: Walnut 예측값: Walnut 17293
# label값: Walnut 예측값: Walnut 17294
# label값: Walnut 예측값: Walnut 17295
# label값: Walnut 예측값: Walnut 17296
# label값: Walnut 예측값: Walnut 17297
# label값: Walnut 예측값: Walnut 17298
# label값: Walnut 예측값: Walnut 17299
# label값: Walnut 예측값: Walnut 17300
# label값: Walnut 예측값: Walnut 17301
# label값: Walnut 예측값: Walnut 17302
# label값: Walnut 예측값: Walnut 17303
# label값: Walnut 예측값: Walnut 17304
# label값: Walnut 예측값: Walnut 17305
# label값: Walnut 예측값: Walnut 17306
# label값: Walnut 예측값: Walnut 17307
# label값: Walnut 예측값: Walnut 17308
# label값: Walnut 예측값: Walnut 17309
# label값: Walnut 예측값: Walnut 17310
# label값: Walnut 예측값: Walnut 17311
# label값: Walnut 예측값: Walnut 17312
# label값: Walnut 예측값: Walnut 17313
# label값: Walnut 예측값: Walnut 17314
# label값: Walnut 예측값: Walnut 17315
# label값: Walnut 예측값: Walnut 17316
# label값: Walnut 예측값: Walnut 17317
# label값: Walnut 예측값: Walnut 17318
# label값: Walnut 예측값: Walnut 17319
# label값: Walnut 예측값: Walnut 17320
# label값: Walnut 예측값: Walnut 17321
# label값: Walnut 예측값: Walnut 17322
# label값: Walnut 예측값: Walnut 17323
# label값: Walnut 예측값: Walnut 17324
# label값: Walnut 예측값: Walnut 17325
# label값: Walnut 예측값: Walnut 17326
# label값: Walnut 예측값: Walnut 17327
# label값: Walnut 예측값: Walnut 17328
# label값: Walnut 예측값: Walnut 17329
# label값: Walnut 예측값: Walnut 17330
# label값: Walnut 예측값: Walnut 17331
# label값: Walnut 예측값: Walnut 17332
# label값: Walnut 예측값: Walnut 17333
# label값: Walnut 예측값: Walnut 17334
# label값: Walnut 예측값: Walnut 17335
# label값: Walnut 예측값: Walnut 17336
# label값: Walnut 예측값: Walnut 17337
# label값: Walnut 예측값: Walnut 17338
# label값: Walnut 예측값: Walnut 17339
# label값: Walnut 예측값: Walnut 17340
# label값: Walnut 예측값: Walnut 17341
# label값: Walnut 예측값: Walnut 17342
# label값: Walnut 예측값: Walnut 17343
# label값: Walnut 예측값: Walnut 17344
# label값: Walnut 예측값: Walnut 17345
# label값: Walnut 예측값: Walnut 17346
# label값: Walnut 예측값: Walnut 17347
# label값: Walnut 예측값: Walnut 17348
# label값: Walnut 예측값: Walnut 17349
# label값: Walnut 예측값: Walnut 17350
# label값: Walnut 예측값: Walnut 17351
# label값: Walnut 예측값: Walnut 17352
# label값: Walnut 예측값: Walnut 17353
# label값: Walnut 예측값: Walnut 17354
# label값: Walnut 예측값: Walnut 17355
# label값: Walnut 예측값: Walnut 17356
# label값: Walnut 예측값: Walnut 17357
# label값: Walnut 예측값: Walnut 17358
# label값: Walnut 예측값: Walnut 17359
# label값: Walnut 예측값: Walnut 17360
# label값: Walnut 예측값: Walnut 17361
# label값: Walnut 예측값: Walnut 17362
# label값: Walnut 예측값: Walnut 17363
# label값: Walnut 예측값: Walnut 17364
# label값: Walnut 예측값: Walnut 17365
# label값: Walnut 예측값: Walnut 17366
# label값: Walnut 예측값: Walnut 17367
# label값: Walnut 예측값: Walnut 17368
# label값: Walnut 예측값: Walnut 17369
# label값: Walnut 예측값: Walnut 17370
# label값: Walnut 예측값: Walnut 17371
# label값: Walnut 예측값: Walnut 17372
# label값: Walnut 예측값: Walnut 17373
# label값: Walnut 예측값: Walnut 17374
# label값: Walnut 예측값: Walnut 17375
# label값: Walnut 예측값: Walnut 17376
# label값: Walnut 예측값: Walnut 17377
# label값: Walnut 예측값: Walnut 17378
# label값: Walnut 예측값: Walnut 17379
# label값: Walnut 예측값: Walnut 17380
# label값: Walnut 예측값: Walnut 17381
# label값: Walnut 예측값: Walnut 17382
# label값: Walnut 예측값: Walnut 17383
# label값: Walnut 예측값: Walnut 17384
# label값: Walnut 예측값: Walnut 17385
# label값: Walnut 예측값: Walnut 17386
# label값: Walnut 예측값: Walnut 17387
# label값: Walnut 예측값: Walnut 17388
# label값: Walnut 예측값: Walnut 17389
# label값: Walnut 예측값: Walnut 17390
# label값: Walnut 예측값: Walnut 17391
# label값: Walnut 예측값: Walnut 17392
# label값: Walnut 예측값: Walnut 17393
# label값: Walnut 예측값: Walnut 17394
# label값: Walnut 예측값: Walnut 17395
# label값: Walnut 예측값: Walnut 17396
# label값: Walnut 예측값: Walnut 17397
# label값: Walnut 예측값: Walnut 17398
# label값: Walnut 예측값: Walnut 17399
# label값: Walnut 예측값: Walnut 17400
# label값: Walnut 예측값: Walnut 17401
# label값: Walnut 예측값: Walnut 17402
# label값: Walnut 예측값: Walnut 17403
# label값: Walnut 예측값: Walnut 17404
# label값: Walnut 예측값: Walnut 17405
# label값: Walnut 예측값: Walnut 17406
# label값: Walnut 예측값: Walnut 17407
# label값: Walnut 예측값: Walnut 17408
# label값: Walnut 예측값: Walnut 17409
# label값: Walnut 예측값: Walnut 17410
# label값: Walnut 예측값: Walnut 17411
# label값: Walnut 예측값: Walnut 17412
# label값: Walnut 예측값: Walnut 17413
# label값: Walnut 예측값: Walnut 17414
# label값: Walnut 예측값: Walnut 17415
# label값: Walnut 예측값: Walnut 17416
# label값: Walnut 예측값: Walnut 17417
# label값: Walnut 예측값: Walnut 17418
# label값: Walnut 예측값: Walnut 17419
# label값: Walnut 예측값: Walnut 17420
# label값: Walnut 예측값: Walnut 17421
# label값: Walnut 예측값: Walnut 17422
# label값: Walnut 예측값: Walnut 17423
# label값: Walnut 예측값: Walnut 17424
# label값: Walnut 예측값: Walnut 17425
# label값: Walnut 예측값: Walnut 17426
# label값: Walnut 예측값: Walnut 17427
# label값: Walnut 예측값: Walnut 17428
# label값: Walnut 예측값: Walnut 17429
# label값: Walnut 예측값: Walnut 17430
# label값: Walnut 예측값: Walnut 17431
# label값: Walnut 예측값: Walnut 17432
# label값: Walnut 예측값: Walnut 17433
# label값: Walnut 예측값: Walnut 17434
# label값: Walnut 예측값: Walnut 17435
# label값: Walnut 예측값: Walnut 17436
# label값: Walnut 예측값: Walnut 17437
# label값: Walnut 예측값: Walnut 17438
# label값: Walnut 예측값: Walnut 17439
# label값: Walnut 예측값: Walnut 17440
# label값: Walnut 예측값: Walnut 17441
# label값: Walnut 예측값: Walnut 17442
# label값: Walnut 예측값: Walnut 17443
# label값: Walnut 예측값: Walnut 17444
# label값: Walnut 예측값: Walnut 17445
# label값: Walnut 예측값: Walnut 17446
# label값: Walnut 예측값: Walnut 17447
# label값: Walnut 예측값: Walnut 17448
# label값: Walnut 예측값: Walnut 17449
# label값: Walnut 예측값: Walnut 17450
# label값: Walnut 예측값: Walnut 17451
# label값: Walnut 예측값: Walnut 17452
# label값: Walnut 예측값: Walnut 17453
# label값: Walnut 예측값: Walnut 17454
# label값: Walnut 예측값: Walnut 17455
# label값: Walnut 예측값: Walnut 17456
# label값: Walnut 예측값: Walnut 17457
# label값: Walnut 예측값: Walnut 17458
# label값: Walnut 예측값: Walnut 17459
# label값: Walnut 예측값: Walnut 17460
# label값: Walnut 예측값: Walnut 17461
# label값: Walnut 예측값: Walnut 17462
# label값: Walnut 예측값: Walnut 17463
# label값: Walnut 예측값: Walnut 17464
# label값: Walnut 예측값: Walnut 17465
# label값: Walnut 예측값: Walnut 17466
# label값: Walnut 예측값: Walnut 17467
# label값: Walnut 예측값: Walnut 17468
# label값: Walnut 예측값: Walnut 17469
# label값: Walnut 예측값: Walnut 17470
# label값: Walnut 예측값: Walnut 17471
# label값: Walnut 예측값: Walnut 17472
# label값: Walnut 예측값: Walnut 17473
# label값: Walnut 예측값: Walnut 17474
# label값: Walnut 예측값: Walnut 17475
# label값: Walnut 예측값: Walnut 17476
# label값: Walnut 예측값: Walnut 17477
# label값: Walnut 예측값: Walnut 17478
# label값: Walnut 예측값: Walnut 17479
# label값: Walnut 예측값: Walnut 17480
# label값: Walnut 예측값: Walnut 17481
# label값: Walnut 예측값: Walnut 17482
# label값: Walnut 예측값: Walnut 17483
# label값: Walnut 예측값: Walnut 17484
# label값: Walnut 예측값: Walnut 17485
# label값: Walnut 예측값: Walnut 17486
# label값: Walnut 예측값: Walnut 17487
# label값: Walnut 예측값: Walnut 17488
# label값: Walnut 예측값: Walnut 17489
# label값: Walnut 예측값: Walnut 17490
# label값: Walnut 예측값: Walnut 17491
# label값: Walnut 예측값: Walnut 17492
# label값: Walnut 예측값: Walnut 17493
# label값: Walnut 예측값: Walnut 17494
# label값: Walnut 예측값: Walnut 17495
# label값: Walnut 예측값: Walnut 17496
# label값: Walnut 예측값: Walnut 17497
# label값: Walnut 예측값: Walnut 17498
# label값: Walnut 예측값: Walnut 17499
# label값: Walnut 예측값: Walnut 17500
# label값: Walnut 예측값: Walnut 17501
# label값: Walnut 예측값: Walnut 17502
# label값: Walnut 예측값: Walnut 17503
# label값: Walnut 예측값: Walnut 17504
# label값: Walnut 예측값: Walnut 17505
# label값: Walnut 예측값: Walnut 17506
# label값: Walnut 예측값: Walnut 17507
# label값: Walnut 예측값: Walnut 17508
# label값: Walnut 예측값: Walnut 17509
# label값: Walnut 예측값: Walnut 17510
# label값: Walnut 예측값: Walnut 17511
# label값: Walnut 예측값: Walnut 17512
# label값: Walnut 예측값: Walnut 17513
# label값: Walnut 예측값: Walnut 17514
# label값: Walnut 예측값: Walnut 17515
# label값: Walnut 예측값: Walnut 17516
# label값: Walnut 예측값: Walnut 17517
# label값: Walnut 예측값: Walnut 17518
# label값: Walnut 예측값: Walnut 17519
# label값: Walnut 예측값: Walnut 17520
# label값: Walnut 예측값: Walnut 17521
# label값: Walnut 예측값: Walnut 17522
# label값: Walnut 예측값: Walnut 17523
# label값: Walnut 예측값: Walnut 17524
# label값: Walnut 예측값: Walnut 17525
# label값: Walnut 예측값: Walnut 17526
# label값: Walnut 예측값: Walnut 17527
# label값: Walnut 예측값: Walnut 17528
# label값: Walnut 예측값: Walnut 17529
# label값: Walnut 예측값: Walnut 17530
# label값: Walnut 예측값: Walnut 17531
# label값: Walnut 예측값: Walnut 17532
# label값: Walnut 예측값: Walnut 17533
# label값: Walnut 예측값: Walnut 17534
# label값: Walnut 예측값: Walnut 17535
# label값: Walnut 예측값: Walnut 17536
# label값: Walnut 예측값: Walnut 17537
# label값: Walnut 예측값: Walnut 17538
# label값: Walnut 예측값: Walnut 17539

# %%
img, label = test_dataset[12666]
plt.imshow(img.permute(1, 2, 0))
print('label값:', dataset.classes[label], '예측값:', predict_image(img, model))

# %%
img, label = test_dataset[5000]
plt.imshow(img.permute(1, 2, 0))
print('label값:', dataset.classes[label], '예측값:', predict_image(img, model))
# Out:
# label값: Clementine 예측값: Clementine
